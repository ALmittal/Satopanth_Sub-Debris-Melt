# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'F:\Biases.csv')
df.head()
# Out:
#       Day        1D        2D        5D       10D       15D
# 0  153.01  5.092009  5.791566  5.921324  4.369773  4.500665
# 1  153.02  5.092009  5.791566  5.921324  4.369773  4.500665
# 2  153.03  5.092009  5.791566  5.921324  4.369773  4.500665
# 3  153.04  5.092009  5.791566  5.921324  4.369773  4.500665
# 4  153.05  5.092009  5.791566  5.921324  4.369773  4.500665

# %%
day = df['Day']
bias_1D = df['1D']
bias_2D = df['2D']
bias_5D = df['5D']
bias_10D = df['10D']
bias_15D = df['15D']
plt.rcParams['figure.dpi'] = 180

plt.plot(day, bias_1D, label='1 Day', color='#FF80ED', linewidth=1)
plt.plot(day, bias_2D, label='2 Day', color='#8FF7FE', linewidth=1)
plt.plot(day, bias_5D, label='5 Day', color='#63FE83', linewidth=1)
plt.plot(day, bias_10D, label='10 Day', color='#5964FF', linewidth=1)
plt.plot(day, bias_15D, label='15 Day', color='r', linewidth=2)
plt.legend()
plt.xlabel('Julian day of 2017')
plt.ylabel('Temperature Bias in °C')
# Out:
# Text(0, 0.5, 'Temperature Bias in °C')
