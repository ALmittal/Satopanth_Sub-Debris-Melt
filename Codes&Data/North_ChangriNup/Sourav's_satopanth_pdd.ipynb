# %%
file_stakeData = open(r'C:\Users\Abhilash Mittal\Desktop\stake_Pdd_data.txt')
jd2 = []
db_thickness = []
pdd = []
for line in file_stakeData:
    jd2.append(int(line.split()[2]))
    db_thickness.append(float(line.split()[5]))
    pdd.append(float(line.split()[7])/24)
    print(float(line.split()[7])/24)
# Out:
# 186.37502896336142
# 155.8489756145717
# 109.89519949177975
# 79.25254983927493
# 128.5934793596742
# 121.8450880077686
# 184.67282460196552
# 153.70081670041668
# 108.08791567633614
# 78.02909389330291
# 126.00858549934372
# 185.21036282135367
# 154.3452643746632
# 108.99155758405794
# 78.6086256571844
# 127.36699352537153
# 53.52521278199106
# 100.08641908259767
# 132.67730341733005
# 191.12955114318314
# 185.83749074397323
# 155.09711999461746
# 188.1288454863951
# 109.26265015637448
# 78.93058774822966
# 127.91209834061715
# 158.54417769904057
# 184.9415937116596
# 154.02304053753994
# 108.44937243942486
# 78.22227114793007
# 126.5515868425196
# 183.86651727288324
# 152.73414518904693
# 184.72420008880795
# 107.36500215015867
# 77.44956212942144
# 124.79050780093166
# 128.53280743539491
# 180.28292914362873
# 148.54523530644465
# 103.75043451927145
# 74.93825781926836
# 119.41183247810052
# 57.41198717633665
# 94.60900044187001
# 127.4819644076219
# 128.718376695369
# ...
